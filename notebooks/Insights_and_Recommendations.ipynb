# %%
import sys
import os
import importlib
sys.path.append(os.path.abspath(".."))
import src.insight_analyzer
importlib.reload(src.insight_analyzer)

from src.insight_analyzer import InsightAnalyzer

analyzer = InsightAnalyzer("../data/sentiment_themes_labeled.csv")

analyzer.sentiment_distribution()

analyzer.sentiment_score_by_rating()

analyzer.theme_distribution()
analyzer.theme_ratio_by_bank()

analyzer.wordcloud_per_bank()
